# %%
import numpy as np
import math
        
class Function:
    evalulate = ()
    differentiate = ()
    args = []
    
    def __init__(self, ev, dif):
        self.evaluate = ev
        self.differentiate = dif
        
    def supplyArgs(params):
        self.args = params
        
def product(args):
    return np.prod(args)

def product_d(args):
    total = np.prod(args)
    return [total/i for i in args]

funcProd = Function(product, product_d)

def exponential(args):
    return np.exp(args[0])

def exponential_d(args):
    return [exponentail(args)]

funcExp = Function(exponential, exponential_d)

def sigmoid(args):
    x = args[0]
    return 1/(1 + np.exp(-x))

def sigmoid_d(args):
    return [sigmoid(args) * (1-sigmoid(args))]

funcSig = Function(sigmoid, sigmoid_d)

def arctan(args):
    x = args[0]
    return np.arctan(x)

def arctan_d(args):
    x = args[0]
    return [1/(1 + x*x)]

funcArcTan = Function(arctan, arctan_d)

def ReLU(args):
    x = args[0]
    return x if x>=0 else 0

def ReLU_d(args):
    x = args[0]
    return [1 if x>=0 else 0]

funcReLU = Function(ReLU, ReLU_d)
